# %%
import pandas as pd
import json

df = pd.read_csv("/content/diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
json_manual_diabetes = [
    {
        "Pregnancies": 6,
        "Glucose": 148,
        "BloodPressure": 72,
        "BMI": 33.6,
        "Age": 50,
        "Outcome": 1
    },
    {
        "Pregnancies": 1,
        "Glucose": 85,
        "BloodPressure": 66,
        "BMI": 26.6,
        "Age": 31,
        "Outcome": 0
    },
    {
        "Pregnancies": 8,
        "Glucose": 183,
        "BloodPressure": 64,
        "BMI": 23.3,
        "Age": 32,
        "Outcome": 1
    }
]

# %%
# Menampilkan hasil format JSON
print("\n--- Format JSON Manual yang Saya Buat ---")
print(json.dumps(json_manual_diabetes, indent=4))
# Out:
# --- Format JSON Manual yang Saya Buat ---
# [
#     {
#         "Pregnancies": 6,
#         "Glucose": 148,
#         "BloodPressure": 72,
#         "BMI": 33.6,
#         "Age": 50,
#         "Outcome": 1
#     },
#     {
#         "Pregnancies": 1,
#         "Glucose": 85,
#         "BloodPressure": 66,
#         "BMI": 26.6,
#         "Age": 31,
#         "Outcome": 0
#     },
#     {
#         "Pregnancies": 8,
#         "Glucose": 183,
#         "BloodPressure": 64,
#         "BMI": 23.3,
#         "Age": 32,
#         "Outcome": 1
#     }
# ]

# %%
# Mengonversi list JSON di atas kembali menjadi file CSV
df_hasil_akhir = pd.DataFrame(json_manual_diabetes)
df_hasil_akhir.to_csv('diabetes_konversi_tugas1.csv', index=False)

print("\nBerhasil! File '/content/diabetes.csv' sudah selesai.")
# Out:
# Berhasil! File '/content/diabetes.csv' sudah selesai.
